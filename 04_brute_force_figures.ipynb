# %%
import ast
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the csv file
final_df = pd.read_csv('Data/Brute_force/collated_results3.csv')

# Filter rows where both 'Microbe' and 'Interacting Microbe' start with 'Bacteria'
final_df = final_df[(final_df['Microbe'].str.startswith('Bacteria')) & (final_df['Interaction Microbe'].str.startswith('Bacteria'))]

# Sort values based on 'Averaged R2'
final_df = final_df.sort_values('R2', ascending = False)

# Print the shape of the dataframe
print(final_df.shape)

# Display the top rows of the dataframe
final_df.head()
# Out:
# (440232, 5)
#    Unnamed: 0                               Microbe  \
# 0      393656       Bacteria_Patulibacter_brassicae
# 1      344864  Bacteria_Mesorhizobium_opportunistum
# 2      250436     Bacteria_Planctomyces_sp._SH-PL14
# 3      319314           Bacteria_Nitrosospira_lacus
# 4       21262          Bacteria_Dokdonella_fugitiva
#
#                   Interaction Microbe  \
# 0  Bacteria_Sphingomonas_sediminicola
# 1         Bacteria_Nitrosospira_lacus
# 2         Bacteria_Nitrosospira_lacus
# 3    Bacteria_Mesorhizobium_japonicum
# 4         Bacteria_Nitrosospira_lacus
#
#                                   Feature Importance        R2
# 0  {'Bacteria_Patulibacter_brassicae': 0.08318639...  0.578298
# 1  {'Bacteria_Mesorhizobium_opportunistum': 0.003...  0.510694
# 2  {'Bacteria_Planctomyces_sp._SH-PL14': 0.087813...  0.503452
# 3  {'Bacteria_Nitrosospira_lacus': 0.333182826547...  0.489512
# 4  {'Bacteria_Dokdonella_fugitiva': 0.02120302892...  0.485206

# %%
def count_reverse_duplicates(df):
    # Create a column to hold sorted tuple of 'Microbe' and 'Interaction Microbe'
    df['sorted_combination'] = df.apply(lambda x: tuple(sorted([x['Microbe'], x['Interaction Microbe']])), axis=1)
    
    # Group by the sorted combination and count
    duplicate_counts = df.groupby('sorted_combination').size().reset_index(name='counts')
    
    # Filter to find combinations that appear more than once (reverse duplicates)
    reverse_duplicates = duplicate_counts[duplicate_counts['counts'] > 1]
    
    return reverse_duplicates

# Apply the function on your dataframe
reverse_duplicates = count_reverse_duplicates(final_df)
print(len(reverse_duplicates))
# Out:
# 220116

# %%
# Create a column to hold sorted tuple of 'Microbe' and 'Interaction Microbe'
final_df['sorted_combination'] = final_df.apply(lambda x: tuple(sorted([x['Microbe'], x['Interaction Microbe']])), axis=1)

# Drop duplicates based on the sorted combination
final_df_deduplicated = final_df.drop_duplicates(subset='sorted_combination', keep='first').drop(columns=['sorted_combination'])

# Resetting index for better data readability
final_df_deduplicated = final_df_deduplicated.reset_index(drop=True)
final_df_deduplicated = final_df_deduplicated.iloc[:2000, :]
print(final_df_deduplicated.shape)
# Out:
# (2000, 5)

# %%
final_df_deduplicated.head(n = 50)
# Out:
#     Unnamed: 0                                  Microbe  \
# 0       393656          Bacteria_Patulibacter_brassicae
# 1       344864     Bacteria_Mesorhizobium_opportunistum
# 2       250436        Bacteria_Planctomyces_sp._SH-PL14
# 3       319314              Bacteria_Nitrosospira_lacus
# 4        21262             Bacteria_Dokdonella_fugitiva
# 5       384180        Bacteria_Geobacter_uraniireducens
# 6       319083              Bacteria_Nitrosospira_lacus
# 7       318785              Bacteria_Nitrosospira_lacus
# 8       318995              Bacteria_Nitrosospira_lacus
# 9       319064              Bacteria_Nitrosospira_lacus
# 10      297076               Bacteria_Taonella_mepensis
# 11      235052        Bacteria_Nitrosospira_multiformis
# 12       60789  Bacteria_Rhodanobacter_lindaniclasticus
# 13      111430        Bacteria_Paludibaculum_fermentans
# 14      414667           Bacteria_Arthrobacter_sp._FB24
# 15      319367              Bacteria_Nitrosospira_lacus
# 16      415355           Bacteria_Archangium_disciforme
# 17      430314        Bacteria_Bradyrhizobium_mercantei
# 18      152332        Bacteria_Stenotrophobacter_terrae
# 19      301221           Bacteria_Gemmata_obscuriglobus
# 20      319185              Bacteria_Nitrosospira_lacus
# 21       99614            Bacteria_Variovorax_paradoxus
# 22      318799              Bacteria_Nitrosospira_lacus
# 23      318738              Bacteria_Nitrosospira_lacus
# 24      346631              Bacteria_Frateuria_aurantia
# 25       99800            Bacteria_Variovorax_paradoxus
# 26      318915              Bacteria_Nitrosospira_lacus
# 27      319286              Bacteria_Nitrosospira_lacus
# 28      239376       Bacteria_Sphingomonas_sediminicola
# 29      318830              Bacteria_Nitrosospira_lacus
# 30      318857              Bacteria_Nitrosospira_lacus
# 31      338581            Bacteria_Adhaeribacter_terrae
# 32      394337               Bacteria_Devosia_submarina
# 33      319072              Bacteria_Nitrosospira_lacus
# 34      318875              Bacteria_Nitrosospira_lacus
# 35      103294           Bacteria_Nitrosospira_briensis
# 36      309130  Bacteria_Parviterribacter_kavangonensis
# 37      319355              Bacteria_Nitrosospira_lacus
# 38         227    Bacteria_Sporocytophaga_myxococcoides
# 39      239171       Bacteria_Sphingomonas_sediminicola
# 40      382012               Bacteria_Skermanella_rosea
# 41      318767              Bacteria_Nitrosospira_lacus
# 42      318858              Bacteria_Nitrosospira_lacus
# 43      185948          Bacteria_Arthrobacter_sp._PGP41
# 44      174807   Bacteria_Paraburkholderia_pallidirosea
# 45      371600             Bacteria_Solitalea_koreensis
# 46      319353              Bacteria_Nitrosospira_lacus
# 47      392328         Bacteria_Microvirga_massiliensis
# 48      271908         Bacteria_Azospirillum_sp._TSH100
# 49      260783     Bacteria_Rhodanobacter_denitrificans
#
#                                   Interaction Microbe  \
# 0                  Bacteria_Sphingomonas_sediminicola
# 1                         Bacteria_Nitrosospira_lacus
# 2                         Bacteria_Nitrosospira_lacus
# 3                    Bacteria_Mesorhizobium_japonicum
# 4                         Bacteria_Nitrosospira_lacus
# 5                  Bacteria_Sphingomonas_sediminicola
# 6                      Bacteria_Rathayibacter_tritici
# 7                      Bacteria_Nitrosospira_briensis
# 8   Bacteria_Mesorhizobium_sp._M9A.F.Ca.ET.002.03.1.2
# 9                     Bacteria_Rhodoplanes_azumiensis
# 10                        Bacteria_Nitrosospira_lacus
# 11                     Bacteria_Nitrosospira_briensis
# 12                        Bacteria_Nitrosospira_lacus
# 13                        Bacteria_Nitrosospira_lacus
# 14                        Bacteria_Nitrosospira_lacus
# 15                         Bacteria_Chryseolinea_soli
# 16                        Bacteria_Nitrosospira_lacus
# 17                        Bacteria_Nitrosospira_lacus
# 18                        Bacteria_Nitrosospira_lacus
# 19                        Bacteria_Nitrosospira_lacus
# 20                     Bacteria_Acidipila_dinghuensis
# 21                  Bacteria_Friedmanniella_spumicola
# 22             Bacteria_Thermoanaerobaculum_aquaticum
# 23                     Bacteria_Caulobacter_mirabilis
# 24                        Bacteria_Nitrosospira_lacus
# 25             Bacteria_Noviherbaspirillum_sp._UKPF54
# 26                           Bacteria_Terrimonas_soli
# 27               Bacteria_Stenotrophomonas_rhizophila
# 28                     Bacteria_Youhaiella_tibetensis
# 29                  Bacteria_Clostridium_subterminale
# 30                Bacteria_Asticcacaulis_benevestitus
# 31                        Bacteria_Nitrosospira_lacus
# 32                        Bacteria_Nitrosospira_lacus
# 33                 Bacteria_Acidisphaera_rubrifaciens
# 34                         Bacteria_Ensifer_adhaerens
# 35                 Bacteria_Sphingomonas_sediminicola
# 36                 Bacteria_Sphingomonas_sediminicola
# 37                Bacteria_Mucilaginibacter_gynuensis
# 38                        Bacteria_Nitrosospira_lacus
# 39                        Bacteria_Nitrosospira_lacus
# 40                    Bacteria_Legionella_pneumophila
# 41          Bacteria_Pullulanibacillus_uraniitolerans
# 42                     Bacteria_Pseudomonas_synxantha
# 43                       Bacteria_Paraflavitalea_soli
# 44                        Bacteria_Nitrosospira_lacus
# 45                        Bacteria_Nitrosospira_lacus
# 46                        Bacteria_Bacillus_sp._OxB-1
# 47                        Bacteria_Nitrosospira_lacus
# 48                        Bacteria_Nitrosospira_lacus
# 49                        Bacteria_Nitrosospira_lacus
#
#                                    Feature Importance        R2
# 0   {'Bacteria_Patulibacter_brassicae': 0.08318639...  0.578298
# 1   {'Bacteria_Mesorhizobium_opportunistum': 0.003...  0.510694
# 2   {'Bacteria_Planctomyces_sp._SH-PL14': 0.087813...  0.503452
# 3   {'Bacteria_Nitrosospira_lacus': 0.333182826547...  0.489512
# 4   {'Bacteria_Dokdonella_fugitiva': 0.02120302892...  0.485206
# 5   {'Bacteria_Geobacter_uraniireducens': 0.008699...  0.481874
# 6   {'Bacteria_Nitrosospira_lacus': 0.298813971563...  0.481862
# 7   {'Bacteria_Nitrosospira_lacus': 0.190575376680...  0.470386
# 8   {'Bacteria_Nitrosospira_lacus': 0.196304484301...  0.469384
# 9   {'Bacteria_Nitrosospira_lacus': 0.188307947192...  0.466317
# 10  {'Bacteria_Taonella_mepensis': 0.0089425239372...  0.464813
# 11  {'Bacteria_Nitrosospira_multiformis': 0.099137...  0.462202
# 12  {'Bacteria_Rhodanobacter_lindaniclasticus': 0....  0.461008
# 13  {'Bacteria_Paludibaculum_fermentans': 0.073014...  0.460988
# 14  {'Bacteria_Arthrobacter_sp._FB24': 0.135909366...  0.457416
# 15  {'Bacteria_Nitrosospira_lacus': 0.171181654669...  0.457253
# 16  {'Bacteria_Archangium_disciforme': 0.009133831...  0.457012
# 17  {'Bacteria_Bradyrhizobium_mercantei': 0.054077...  0.455248
# 18  {'Bacteria_Stenotrophobacter_terrae': 0.123555...  0.453302
# 19  {'Bacteria_Gemmata_obscuriglobus': 0.080211174...  0.452665
# 20  {'Bacteria_Nitrosospira_lacus': 0.209782849510...  0.451531
# 21  {'Bacteria_Variovorax_paradoxus': 0.0959519332...  0.450824
# 22  {'Bacteria_Nitrosospira_lacus': 0.256099494466...  0.447250
# 23  {'Bacteria_Nitrosospira_lacus': 0.260185291209...  0.446442
# 24  {'Bacteria_Frateuria_aurantia': 0.067025353379...  0.443962
# 25  {'Bacteria_Variovorax_paradoxus': 0.1501942752...  0.443079
# 26  {'Bacteria_Nitrosospira_lacus': 0.170850017233...  0.442761
# 27  {'Bacteria_Nitrosospira_lacus': 0.290507739542...  0.441475
# 28  {'Bacteria_Sphingomonas_sediminicola': 0.23352...  0.440695
# 29  {'Bacteria_Nitrosospira_lacus': 0.202379973873...  0.439991
# 30  {'Bacteria_Nitrosospira_lacus': 0.268250359373...  0.439054
# 31  {'Bacteria_Adhaeribacter_terrae': 0.0159424776...  0.439018
# 32  {'Bacteria_Devosia_submarina': 0.0056473766292...  0.438636
# 33  {'Bacteria_Nitrosospira_lacus': 0.259291286029...  0.438206
# 34  {'Bacteria_Nitrosospira_lacus': 0.207782281447...  0.436109
# 35  {'Bacteria_Nitrosospira_briensis': 0.120231580...  0.435374
# 36  {'Bacteria_Parviterribacter_kavangonensis': 0....  0.434751
# 37  {'Bacteria_Nitrosospira_lacus': 0.272648867089...  0.434467
# 38  {'Bacteria_Sporocytophaga_myxococcoides': 0.03...  0.434259
# 39  {'Bacteria_Sphingomonas_sediminicola': 0.14189...  0.434074
# 40  {'Bacteria_Skermanella_rosea': 0.1733974892211...  0.433797
# 41  {'Bacteria_Nitrosospira_lacus': 0.235105883038...  0.432561
# 42  {'Bacteria_Nitrosospira_lacus': 0.305866899057...  0.432170
# 43  {'Bacteria_Arthrobacter_sp._PGP41': 0.08805604...  0.431346
# 44  {'Bacteria_Paraburkholderia_pallidirosea': 0.0...  0.430341
# 45  {'Bacteria_Solitalea_koreensis': 0.01399707040...  0.429652
# 46  {'Bacteria_Nitrosospira_lacus': 0.245448456660...  0.428609
# 47  {'Bacteria_Microvirga_massiliensis': 0.1853094...  0.426809
# 48  {'Bacteria_Azospirillum_sp._TSH100': 0.0283231...  0.426168
# 49  {'Bacteria_Rhodanobacter_denitrificans': 0.016...  0.426160

# %%
# Concatenate values from 'Microbe' and 'Interaction Microbe'
all_microbes = pd.concat([final_df_deduplicated['Microbe'], final_df_deduplicated['Interaction Microbe']])

# Count the occurrences of each microbe
microbe_counts = all_microbes.value_counts()

# Extract the top 10 most common microbes
top_20_microbes = microbe_counts.head(10)
top_20_microbes
# Out:
# Bacteria_Nitrosospira_lacus           566
# Bacteria_Longilinea_arvoryzae         311
# Bacteria_Microlunatus_aurantiacus     188
# Bacteria_Sphingomonas_sediminicola    142
# Bacteria_Paraflavitalea_soli          139
# Bacteria_Brevitalea_deliciosa          94
# Bacteria_Variovorax_paradoxus          90
# Bacteria_Nitrosospira_briensis         77
# Bacteria_Legionella_pneumophila        63
# Bacteria_Povalibacter_uvarum           46
# Name: count, dtype: int64

# %%
# Filter for rows where 'Microbe' or 'Interaction Microbe' is either 'Bacteria_Sphingomonas_sediminicola' or 'Bacteria_Nitrosospira_lacus'
filtered_df = final_df_deduplicated[
    (final_df_deduplicated['Microbe'].isin(['Bacteria_Sphingomonas_sediminicola', 'Bacteria_Nitrosospira_lacus'])) & 
    (final_df_deduplicated['Interaction Microbe'].isin(['Bacteria_Sphingomonas_sediminicola', 'Bacteria_Nitrosospira_lacus']))
]

# Display the filtered dataframe
filtered_df
# Out:
#     Unnamed: 0                             Microbe  \
# 39      239171  Bacteria_Sphingomonas_sediminicola
#
#             Interaction Microbe  \
# 39  Bacteria_Nitrosospira_lacus
#
#                                    Feature Importance        R2
# 39  {'Bacteria_Sphingomonas_sediminicola': 0.14189...  0.434074

# %%
# Checking for duplicates
duplicates = final_df_deduplicated[final_df_deduplicated.duplicated(subset=['Microbe', 'Interaction Microbe'], keep=False)]

print(duplicates)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Microbe, Interaction Microbe, Feature Importance, R2]
# Index: []

# %%
def to_dict(val):
    if isinstance(val, str):
        try:
            return ast.literal_eval(val)
        except ValueError:
            return {}
    return val

# Convert all string representations to dictionaries using .loc to prevent the SettingWithCopyWarning
filtered_df.loc[:, 'Feature Importance'] = filtered_df['Feature Importance'].apply(to_dict)

# Initialize dictionaries to store the cumulative importance and occurrence count of each feature
cumulative_importance = {}
feature_count = {}

# Iterate over the 'Feature Importance' column
for feature_dict in filtered_df['Feature Importance']:
    for feature, importance in feature_dict.items():
        # If the feature is already in the dictionaries, add the current importance value and increment count
        if feature in cumulative_importance:
            cumulative_importance[feature] += importance
            feature_count[feature] += 1
        # If not, initialize the feature in the dictionaries with the current importance value and set count to 1
        else:
            cumulative_importance[feature] = importance
            feature_count[feature] = 1

# Convert the cumulative importance values to average by dividing by the occurrence count of each feature
average_importance = {feature: importance / feature_count[feature] for feature, importance in cumulative_importance.items()}

# Convert the average importance dictionary to a pandas DataFrame for better visualization
average_importance_df = pd.DataFrame(list(average_importance.items()), columns=['Feature', 'Average Importance']).sort_values(by='Average Importance', ascending=False)

# Display the average importance dataframe
average_importance_df
# Out:
#                               Feature  Average Importance
# 1                    Water trt target            0.511394
# 3         Bacteria_Nitrosospira_lacus            0.201272
# 2                        N trt target            0.145438
# 0  Bacteria_Sphingomonas_sediminicola            0.141896

# %%
average_importance_df.head(n = 20)
# Out:
#                               Feature  Average Importance
# 1                    Water trt target            0.511394
# 3         Bacteria_Nitrosospira_lacus            0.201272
# 2                        N trt target            0.145438
# 0  Bacteria_Sphingomonas_sediminicola            0.141896

# %% [markdown]
# # Model stacking

# %%
import warnings
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

# %%
# Function to clean column names
def clean_column_names(df):
    new_columns = []
    for col in df.columns:
        cleaned_col = col.replace("[", "").replace("]", "").replace(",", "")
        new_columns.append(cleaned_col)

    df.columns = new_columns
    return df

# %%
# One-hot encode microbial features
dummies = pd.get_dummies(final_df[['Microbe', 'Interaction Microbe']])
X_second_layer = pd.concat([final_df.drop(['Microbe', 'Interaction Microbe'], axis=1), dummies], axis=1)
X_second_layer = X_second_layer.select_dtypes(include=['bool'])

# Apply the function to clean column names
X_second_layer = clean_column_names(X_second_layer)

y_second_layer = final_df["R2"]

# %%
X_second_layer.head()
# Out:
#    Microbe_Bacteria_Achromobacter_insolitus  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    Microbe_Bacteria_Acidibrevibacterium_fodinaquatile  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Microbe_Bacteria_Acidicapsa_acidisoli  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#    Microbe_Bacteria_Acidimicrobium_ferrooxidans  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    Microbe_Bacteria_Acidipila_dinghuensis  Microbe_Bacteria_Acidipila_rosea  \
# 0                                   False                             False
# 1                                   False                             False
# 2                                   False                             False
# 3                                   False                             False
# 4                                   False                             False
#
#    Microbe_Bacteria_Acidisarcina_polymorpha  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    Microbe_Bacteria_Acidisphaera_rubrifaciens  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
#    Microbe_Bacteria_Aciditerrimonas_ferrireducens  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    Microbe_Bacteria_Acidobacterium_capsulatum  ...  \
# 0                                       False  ...
# 1                                       False  ...
# 2                                       False  ...
# 3                                       False  ...
# 4                                       False  ...
#
#    Interaction Microbe_Bacteria_Virgibacillus_kekensis  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Interaction Microbe_Bacteria_Virgibacillus_necropolis  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Interaction Microbe_Bacteria_Virgibacillus_sp._Bac332  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Interaction Microbe_Bacteria_Williamsia_limnetica  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Interaction Microbe_Bacteria_Woeseia_oceani  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
#
#    Interaction Microbe_Bacteria_Youhaiella_tibetensis  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Interaction Microbe_Bacteria_Zavarzinella_formosa  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Interaction Microbe_Bacteria_Zhizhongheella_caldifontis  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Interaction Microbe_Bacteria_Brevibacterium_frigoritolerans  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Interaction Microbe_Bacteria_Desulfotomaculum_salinum
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
# [5 rows x 1328 columns]

# %%
with warnings.catch_warnings():
    warnings.filterwarnings("ignore", category=FutureWarning)
    # Define hyperparameter grid to search

    param_grid = {
        'learning_rate': [0.01, 0.1, 0.3],
        'n_estimators': [50, 100, 200],
        'max_depth': [3, 5, 7]
    }
    
    # Initialize the model
    second_layer_model = xgb.XGBRegressor(n_jobs=-1)
    
    # Initialize and fit GridSearchCV
    grid_search = GridSearchCV(estimator=second_layer_model, param_grid=param_grid, cv=5)
    grid_search.fit(X_second_layer, y_second_layer)
    
    # Extract best estimator and its feature importances
    best_estimator = grid_search.best_estimator_
    importances = best_estimator.feature_importances_

# %%
# Get feature importances
importances = best_estimator.feature_importances_

feature_names = X_second_layer.columns

# Pair feature importances with feature names and sort
feature_importance_pairs = sorted(zip(importances, feature_names), reverse=True)

# Extract the top 20 most important features
top_20_features = feature_importance_pairs[:20]

# Display the top 20 most important features
for importance, feature in top_20_features:
    print(f"{feature}: {importance}")
# Out:
# Microbe_Bacteria_Nitrosospira_lacus: 0.010803837329149246
# Interaction Microbe_Bacteria_Nitrosospira_lacus: 0.010774942114949226
# Microbe_Bacteria_Nitrosospira_briensis: 0.010164840146899223
# Interaction Microbe_Bacteria_Variovorax_paradoxus: 0.010093113407492638
# Interaction Microbe_Bacteria_Rhizomicrobium_electricum: 0.008559852838516235
# Interaction Microbe_Bacteria_Microlunatus_aurantiacus: 0.00842492189258337
# Interaction Microbe_Bacteria_Brevitalea_deliciosa: 0.008417671546339989
# Microbe_Bacteria_Povalibacter_uvarum: 0.007811404298990965
# Interaction Microbe_Bacteria_Nitrosospira_briensis: 0.007806373760104179
# Microbe_Bacteria_Variovorax_paradoxus: 0.007783808279782534
# Interaction Microbe_Bacteria_Geobacter_sp._M18: 0.007699323818087578
# Microbe_Bacteria_Terrimonas_suqianensis: 0.0075937495566904545
# Interaction Microbe_Bacteria_Microlunatus_phosphovorus: 0.007349255960434675
# Microbe_Bacteria_Brevitalea_deliciosa: 0.007098400965332985
# Microbe_Bacteria_Legionella_pneumophila: 0.006994945462793112
# Microbe_Bacteria_Pandoraea_thiooxydans: 0.006987100932747126
# Interaction Microbe_Bacteria_Paraflavitalea_soli: 0.00691346125677228
# Microbe_Bacteria_Caldimonas_hydrothermale: 0.0069047752767801285
# Interaction Microbe_Bacteria_Brevitalea_aridisoli: 0.006891844794154167
# Microbe_Bacteria_Acidibrevibacterium_fodinaquatile: 0.00665845675393939
