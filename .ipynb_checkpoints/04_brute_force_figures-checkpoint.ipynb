# %%
import ast
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the csv file
final_df = pd.read_csv('../collated_results3.csv')

# Filter rows where both 'Microbe' and 'Interacting Microbe' start with 'Bacteria'
final_df = final_df[(final_df['Microbe'].str.startswith('Bacteria')) & (final_df['Interaction Microbe'].str.startswith('Bacteria'))]

# Sort values based on 'Averaged R2'
final_df = final_df.sort_values('R2', ascending = False)

# Print the shape of the dataframe
print(final_df.shape)

# Display the top rows of the dataframe
final_df.head()
# Out:
# (511940, 5)
#    Unnamed: 0                                            Microbe  \
# 0      307964  Bacteria_Candidatus_Saccharibacteria_bacterium...
# 1        3909                        Bacteria_Nitrosospira_lacus
# 2        4040                        Bacteria_Nitrosospira_lacus
# 3        4293                        Bacteria_Nitrosospira_lacus
# 4        1669                          Bacteria_Devosia_sp._I507
#
#                    Interaction Microbe  \
# 0   Bacteria_Sphingomonas_sediminicola
# 1           Bacteria_Reyranella_terrae
# 2  Bacteria_Methylibium_petroleiphilum
# 3    Bacteria_Bradyrhizobium_mercantei
# 4          Bacteria_Nitrosospira_lacus
#
#                                   Feature Importance        R2
# 0  {'Bacteria_Candidatus_Saccharibacteria_bacteri...  0.547459
# 1  {'Bacteria_Nitrosospira_lacus': 0.205791482032...  0.513115
# 2  {'Bacteria_Nitrosospira_lacus': 0.226117117156...  0.512003
# 3  {'Bacteria_Nitrosospira_lacus': 0.229663619571...  0.511190
# 4  {'Bacteria_Devosia_sp._I507': 0.00558376083560...  0.495946

# %%
def count_reverse_duplicates(df):
    # Create a column to hold sorted tuple of 'Microbe' and 'Interaction Microbe'
    df['sorted_combination'] = df.apply(lambda x: tuple(sorted([x['Microbe'], x['Interaction Microbe']])), axis=1)
    
    # Group by the sorted combination and count
    duplicate_counts = df.groupby('sorted_combination').size().reset_index(name='counts')
    
    # Filter to find combinations that appear more than once (reverse duplicates)
    reverse_duplicates = duplicate_counts[duplicate_counts['counts'] > 1]
    
    return reverse_duplicates

# Apply the function on your dataframe
reverse_duplicates = count_reverse_duplicates(final_df)
print(len(reverse_duplicates))
# Out:
# 255970

# %%
# Create a column to hold sorted tuple of 'Microbe' and 'Interaction Microbe'
final_df['sorted_combination'] = final_df.apply(lambda x: tuple(sorted([x['Microbe'], x['Interaction Microbe']])), axis=1)

# Drop duplicates based on the sorted combination
final_df_deduplicated = final_df.drop_duplicates(subset='sorted_combination', keep='first').drop(columns=['sorted_combination'])

# Resetting index for better data readability
final_df_deduplicated = final_df_deduplicated.reset_index(drop=True)
final_df_deduplicated.to_csv('Data/SCINet/collated_deduplicated_results.csv')
final_df_deduplicated = final_df_deduplicated.iloc[:2000, :]
print(final_df_deduplicated.shape)
# Out:
# (2000, 5)

# %%
final_df_deduplicated.head(n = 50)
# Out:
#     Unnamed: 0                                            Microbe  \
# 0       307964  Bacteria_Candidatus_Saccharibacteria_bacterium...
# 1         3909                        Bacteria_Nitrosospira_lacus
# 2         4040                        Bacteria_Nitrosospira_lacus
# 3         4293                        Bacteria_Nitrosospira_lacus
# 4         1669                          Bacteria_Devosia_sp._I507
# 5         4012                        Bacteria_Nitrosospira_lacus
# 6        75620                      Bacteria_Longilinea_arvoryzae
# 7       493640                    Bacteria_Paludisphaera_borealis
# 8         4064                        Bacteria_Nitrosospira_lacus
# 9         4201                        Bacteria_Nitrosospira_lacus
# 10      382467                   Bacteria_Lysobacter_ginsengisoli
# 11      312322                  Bacteria_Arthrobacter_dokdonellae
# 12      473526                     Bacteria_Nitrosospira_briensis
# 13        4163                        Bacteria_Nitrosospira_lacus
# 14      292171                   Bacteria_Thiobacter_subterraneus
# 15      407540                         Bacteria_Skermanella_rosea
# 16      275763             Bacteria_Roseimicrobium_gellanilyticum
# 17        3793                        Bacteria_Nitrosospira_lacus
# 18      441638                      Bacteria_Skermanella_aerolata
# 19      253120                    Bacteria_Nocardioides_sp._JS614
# 20      250182                        Bacteria_Dyella_thiooxydans
# 21        4244                        Bacteria_Nitrosospira_lacus
# 22        4236                        Bacteria_Nitrosospira_lacus
# 23       90290                  Bacteria_Microlunatus_aurantiacus
# 24      324444                 Bacteria_Sphingomonas_sediminicola
# 25        4063                        Bacteria_Nitrosospira_lacus
# 26      452037                    Bacteria_Bacillus_thuringiensis
# 27      494377                        Bacteria_Longispora_urticae
# 28      298984           Bacteria_Schlegelella_thermodepolymerans
# 29       24851                 Bacteria_Paenibacillus_yonginensis
# 30      324604                 Bacteria_Sphingomonas_sediminicola
# 31      271055                  Bacteria_Methylobacterium_sp._WL1
# 32        3762                        Bacteria_Nitrosospira_lacus
# 33      340621                           Bacteria_Terrimonas_soli
# 34        4116                        Bacteria_Nitrosospira_lacus
# 35      371934                  Bacteria_Flavisolibacter_tropicus
# 36        3684                        Bacteria_Nitrosospira_lacus
# 37        4170                        Bacteria_Nitrosospira_lacus
# 38        4292                        Bacteria_Nitrosospira_lacus
# 39        4090                        Bacteria_Nitrosospira_lacus
# 40        3988                        Bacteria_Nitrosospira_lacus
# 41        3752                        Bacteria_Nitrosospira_lacus
# 42        4245                        Bacteria_Nitrosospira_lacus
# 43        3621                        Bacteria_Nitrosospira_lacus
# 44       31008                   Bacteria_Rhizobium_leguminosarum
# 45      169272                  Bacteria_Paenibacillus_taihuensis
# 46      115646                   Bacteria_Thermoactinomyces_daqus
# 47        4069                        Bacteria_Nitrosospira_lacus
# 48        3718                        Bacteria_Nitrosospira_lacus
# 49        4183                        Bacteria_Nitrosospira_lacus
#
#                                   Interaction Microbe  \
# 0                  Bacteria_Sphingomonas_sediminicola
# 1                          Bacteria_Reyranella_terrae
# 2                 Bacteria_Methylibium_petroleiphilum
# 3                   Bacteria_Bradyrhizobium_mercantei
# 4                         Bacteria_Nitrosospira_lacus
# 5                        Bacteria_Arthrobacter_sp._YN
# 6                      Bacteria_Nitrosospira_briensis
# 7                         Bacteria_Nitrosospira_lacus
# 8                  Bacteria_Actinoplanes_sp._N902-109
# 9                   Bacteria_Nocardioides_islandensis
# 10                        Bacteria_Nitrosospira_lacus
# 11                        Bacteria_Nitrosospira_lacus
# 12  Bacteria_Anaerolineaceae_bacterium_oral_taxon_439
# 13                  Bacteria_Arenimonas_daechungensis
# 14                        Bacteria_Nitrosospira_lacus
# 15                        Bacteria_Nitrosospira_lacus
# 16                        Bacteria_Nitrosospira_lacus
# 17                 Bacteria_Burkholderia_sp._CCGE1003
# 18                        Bacteria_Nitrosospira_lacus
# 19                        Bacteria_Nitrosospira_lacus
# 20                        Bacteria_Nitrosospira_lacus
# 21                      Bacteria_Melittangium_boletus
# 22                    Bacteria_Massilia_violaceinigra
# 23                      Bacteria_Skermanella_aerolata
# 24                        Bacteria_Nitrosospira_lacus
# 25                      Bacteria_Paenibacillus_sp._37
# 26                        Bacteria_Nitrosospira_lacus
# 27                 Bacteria_Sphingomonas_sediminicola
# 28                        Bacteria_Nitrosospira_lacus
# 29                        Bacteria_Nitrosospira_lacus
# 30                   Bacteria_Amaricoccus_kaplicensis
# 31                        Bacteria_Nitrosospira_lacus
# 32                        Bacteria_Azoarcus_sp._KH32C
# 33                        Bacteria_Nitrosospira_lacus
# 34            Bacteria_Noviherbaspirillum_massiliense
# 35                        Bacteria_Nitrosospira_lacus
# 36                         Bacteria_Devosia_geojensis
# 37                   Bacteria_Arthrobacter_sp._Rue61a
# 38                 Bacteria_Lysobacter_caseinilyticus
# 39                   Bacteria_Phycicoccus_bigeumensis
# 40                   Bacteria_Burkholderia_sp._DHOD12
# 41                Bacteria_Asticcacaulis_benevestitus
# 42                Bacteria_Granulibacter_bethesdensis
# 43                  Bacteria_Actinoplanes_rhizophilus
# 44                        Bacteria_Nitrosospira_lacus
# 45             Bacteria_Ramlibacter_ginsenosidimutans
# 46                        Bacteria_Nitrosospira_lacus
# 47                           Bacteria_Bacillus_sp._Y1
# 48                            Bacteria_Ilyomonas_limi
# 49                 Bacteria_Cellulomonas_xylanilytica
#
#                                    Feature Importance        R2
# 0   {'Bacteria_Candidatus_Saccharibacteria_bacteri...  0.547459
# 1   {'Bacteria_Nitrosospira_lacus': 0.205791482032...  0.513115
# 2   {'Bacteria_Nitrosospira_lacus': 0.226117117156...  0.512003
# 3   {'Bacteria_Nitrosospira_lacus': 0.229663619571...  0.511190
# 4   {'Bacteria_Devosia_sp._I507': 0.00558376083560...  0.495946
# 5   {'Bacteria_Nitrosospira_lacus': 0.232273489090...  0.495326
# 6   {'Bacteria_Longilinea_arvoryzae': 0.2746430979...  0.494154
# 7   {'Bacteria_Paludisphaera_borealis': 0.02989450...  0.491315
# 8   {'Bacteria_Nitrosospira_lacus': 0.236549634547...  0.486672
# 9   {'Bacteria_Nitrosospira_lacus': 0.224949141406...  0.478289
# 10  {'Bacteria_Lysobacter_ginsengisoli': 0.0185731...  0.477353
# 11  {'Bacteria_Arthrobacter_dokdonellae': 0.006562...  0.474202
# 12  {'Bacteria_Nitrosospira_briensis': 0.373114935...  0.471466
# 13  {'Bacteria_Nitrosospira_lacus': 0.196025904833...  0.469317
# 14  {'Bacteria_Thiobacter_subterraneus': 0.0450867...  0.467741
# 15  {'Bacteria_Skermanella_rosea': 0.1419818954286...  0.465345
# 16  {'Bacteria_Roseimicrobium_gellanilyticum': 0.0...  0.463348
# 17  {'Bacteria_Nitrosospira_lacus': 0.255322899336...  0.463140
# 18  {'Bacteria_Skermanella_aerolata': 0.1095736187...  0.459053
# 19  {'Bacteria_Nocardioides_sp._JS614': 0.01617539...  0.457688
# 20  {'Bacteria_Dyella_thiooxydans': 0.071036485512...  0.455554
# 21  {'Bacteria_Nitrosospira_lacus': 0.276143056467...  0.454324
# 22  {'Bacteria_Nitrosospira_lacus': 0.279543059072...  0.453620
# 23  {'Bacteria_Microlunatus_aurantiacus': 0.230175...  0.450781
# 24  {'Bacteria_Sphingomonas_sediminicola': 0.14176...  0.450309
# 25  {'Bacteria_Nitrosospira_lacus': 0.260447127655...  0.449624
# 26  {'Bacteria_Bacillus_thuringiensis': 0.11486859...  0.449352
# 27  {'Bacteria_Longispora_urticae': 0.011999183519...  0.447089
# 28  {'Bacteria_Schlegelella_thermodepolymerans': 0...  0.446121
# 29  {'Bacteria_Paenibacillus_yonginensis': 0.01170...  0.446097
# 30  {'Bacteria_Sphingomonas_sediminicola': 0.25853...  0.445894
# 31  {'Bacteria_Methylobacterium_sp._WL1': 0.002579...  0.445544
# 32  {'Bacteria_Nitrosospira_lacus': 0.241337400257...  0.444752
# 33  {'Bacteria_Terrimonas_soli': 0.128067819025362...  0.443591
# 34  {'Bacteria_Nitrosospira_lacus': 0.190041482684...  0.443312
# 35  {'Bacteria_Flavisolibacter_tropicus': 0.036481...  0.443174
# 36  {'Bacteria_Nitrosospira_lacus': 0.213565659068...  0.442795
# 37  {'Bacteria_Nitrosospira_lacus': 0.212898270825...  0.441643
# 38  {'Bacteria_Nitrosospira_lacus': 0.235734040265...  0.439284
# 39  {'Bacteria_Nitrosospira_lacus': 0.263096705070...  0.438790
# 40  {'Bacteria_Nitrosospira_lacus': 0.230975131203...  0.438174
# 41  {'Bacteria_Nitrosospira_lacus': 0.253103905832...  0.436369
# 42  {'Bacteria_Nitrosospira_lacus': 0.304187151376...  0.434835
# 43  {'Bacteria_Nitrosospira_lacus': 0.219980485150...  0.434080
# 44  {'Bacteria_Rhizobium_leguminosarum': 0.0432066...  0.433466
# 45  {'Bacteria_Paenibacillus_taihuensis': 0.059581...  0.433393
# 46  {'Bacteria_Thermoactinomyces_daqus': 0.0180203...  0.431519
# 47  {'Bacteria_Nitrosospira_lacus': 0.294720129519...  0.431192
# 48  {'Bacteria_Nitrosospira_lacus': 0.206420498697...  0.430064
# 49  {'Bacteria_Nitrosospira_lacus': 0.233592535180...  0.428057

# %%
# Concatenate values from 'Microbe' and 'Interaction Microbe'
all_microbes = pd.concat([final_df_deduplicated['Microbe'], final_df_deduplicated['Interaction Microbe']])

# Count the occurrences of each microbe
microbe_counts = all_microbes.value_counts()

# Extract the top 10 most common microbes
top_20_microbes = microbe_counts.head(10)
top_20_microbes
# Out:
# Bacteria_Nitrosospira_lacus                   597
# Bacteria_Longilinea_arvoryzae                 234
# Bacteria_Microlunatus_aurantiacus             157
# Bacteria_Sphingomonas_sediminicola            142
# Bacteria_Paraflavitalea_soli                  116
# Bacteria_Sterolibacteriaceae_bacterium_M52    106
# Bacteria_Brevitalea_deliciosa                  94
# Bacteria_Variovorax_paradoxus                  75
# Bacteria_Nitrosospira_briensis                 66
# Bacteria_Povalibacter_uvarum                   50
# Name: count, dtype: int64

# %%
# Filter for rows where 'Microbe' or 'Interaction Microbe' is either 'Bacteria_Sphingomonas_sediminicola' or 'Bacteria_Nitrosospira_lacus'
filtered_df = final_df_deduplicated[
    (final_df_deduplicated['Microbe'].isin(['Bacteria_Sphingomonas_sediminicola', 'Bacteria_Nitrosospira_lacus'])) & 
    (final_df_deduplicated['Interaction Microbe'].isin(['Bacteria_Sphingomonas_sediminicola', 'Bacteria_Nitrosospira_lacus']))
]

# Display the filtered dataframe
filtered_df
# Out:
#     Unnamed: 0                             Microbe  \
# 24      324444  Bacteria_Sphingomonas_sediminicola
#
#             Interaction Microbe  \
# 24  Bacteria_Nitrosospira_lacus
#
#                                    Feature Importance        R2
# 24  {'Bacteria_Sphingomonas_sediminicola': 0.14176...  0.450309

# %%
# Checking for duplicates
duplicates = final_df_deduplicated[final_df_deduplicated.duplicated(subset=['Microbe', 'Interaction Microbe'], keep=False)]

print(duplicates)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Microbe, Interaction Microbe, Feature Importance, R2]
# Index: []

# %%
def to_dict(val):
    if isinstance(val, str):
        try:
            return ast.literal_eval(val)
        except ValueError:
            return {}
    return val

# Convert all string representations to dictionaries using .loc to prevent the SettingWithCopyWarning
filtered_df.loc[:, 'Feature Importance'] = filtered_df['Feature Importance'].apply(to_dict)

# Initialize dictionaries to store the cumulative importance and occurrence count of each feature
cumulative_importance = {}
feature_count = {}

# Iterate over the 'Feature Importance' column
for feature_dict in filtered_df['Feature Importance']:
    for feature, importance in feature_dict.items():
        # If the feature is already in the dictionaries, add the current importance value and increment count
        if feature in cumulative_importance:
            cumulative_importance[feature] += importance
            feature_count[feature] += 1
        # If not, initialize the feature in the dictionaries with the current importance value and set count to 1
        else:
            cumulative_importance[feature] = importance
            feature_count[feature] = 1

# Convert the cumulative importance values to average by dividing by the occurrence count of each feature
average_importance = {feature: importance / feature_count[feature] for feature, importance in cumulative_importance.items()}

# Convert the average importance dictionary to a pandas DataFrame for better visualization
average_importance_df = pd.DataFrame(list(average_importance.items()), columns=['Feature', 'Average Importance']).sort_values(by='Average Importance', ascending=False)

# Display the average importance dataframe
average_importance_df
# Out:
#                               Feature  Average Importance
# 1                    Water trt target            0.507231
# 2                        N trt target            0.181280
# 3         Bacteria_Nitrosospira_lacus            0.169727
# 0  Bacteria_Sphingomonas_sediminicola            0.141762

# %% [markdown]
# # Model stacking

# %%
import warnings
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

# %%
# Function to clean column names
def clean_column_names(df):
    new_columns = []
    for col in df.columns:
        cleaned_col = col.replace("[", "").replace("]", "").replace(",", "")
        new_columns.append(cleaned_col)

    df.columns = new_columns
    return df

# %%
# One-hot encode microbial features
dummies = pd.get_dummies(final_df[['Microbe', 'Interaction Microbe']])
X_second_layer = pd.concat([final_df.drop(['Microbe', 'Interaction Microbe'], axis=1), dummies], axis=1)
X_second_layer = X_second_layer.select_dtypes(include=['bool'])

# Apply the function to clean column names
X_second_layer = clean_column_names(X_second_layer)

y_second_layer = final_df["R2"]

# %%
X_second_layer.head()
# Out:
#    Microbe_Bacteria_Achromobacter_insolitus  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    Microbe_Bacteria_Acidibacter_ferrireducens  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
#    Microbe_Bacteria_Acidibrevibacterium_fodinaquatile  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Microbe_Bacteria_Acidicapsa_acidisoli  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#    Microbe_Bacteria_Acidimicrobium_ferrooxidans  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    Microbe_Bacteria_Acidipila_dinghuensis  Microbe_Bacteria_Acidipila_rosea  \
# 0                                   False                             False
# 1                                   False                             False
# 2                                   False                             False
# 3                                   False                             False
# 4                                   False                             False
#
#    Microbe_Bacteria_Acidisarcina_polymorpha  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    Microbe_Bacteria_Acidisphaera_rubrifaciens  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
#    Microbe_Bacteria_Aciditerrimonas_ferrireducens  ...  \
# 0                                           False  ...
# 1                                           False  ...
# 2                                           False  ...
# 3                                           False  ...
# 4                                           False  ...
#
#    Interaction Microbe_Bacteria_Virgibacillus_necropolis  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Interaction Microbe_Bacteria_Virgibacillus_sp._Bac332  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Interaction Microbe_Bacteria_Williamsia_limnetica  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Interaction Microbe_Bacteria_Woeseia_oceani  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
#
#    Interaction Microbe_Bacteria_Youhaiella_tibetensis  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Interaction Microbe_Bacteria_Zavarzinella_formosa  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Interaction Microbe_Bacteria_Zhizhongheella_caldifontis  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Interaction Microbe_Bacteria_Brevibacterium_frigoritolerans  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Interaction Microbe_Bacteria_Desulfotomaculum_salinum  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Interaction Microbe_Bacteria_Polyangium_brachysporum
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
# [5 rows x 1432 columns]

# %%
with warnings.catch_warnings():
    warnings.filterwarnings("ignore", category=FutureWarning)
    # Define hyperparameter grid to search

    param_grid = {
        'learning_rate': [0.01, 0.1, 0.3],
        'n_estimators': [50, 100, 200],
        'max_depth': [3, 5, 7]
    }
    
    # Initialize the model
    second_layer_model = xgb.XGBRegressor(n_jobs=-1)
    
    # Initialize and fit GridSearchCV
    grid_search = GridSearchCV(estimator=second_layer_model, param_grid=param_grid, cv=5)
    grid_search.fit(X_second_layer, y_second_layer)
    
    # Extract best estimator and its feature importances
    best_estimator = grid_search.best_estimator_
    importances = best_estimator.feature_importances_

# %%
# Get feature importances
importances = best_estimator.feature_importances_

feature_names = X_second_layer.columns

# Pair feature importances with feature names and sort
feature_importance_pairs = sorted(zip(importances, feature_names), reverse=True)

# Extract the top 20 most important features
top_20_features = feature_importance_pairs[:20]

# Display the top 20 most important features
for importance, feature in top_20_features:
    print(f"{feature}: {importance}")
